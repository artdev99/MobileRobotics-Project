# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import cv2
import matplotlib.pyplot as plt

from libs.camera import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ip_camera= True
if ip_camera:
    login= "thymio"
    password= "qwertz"
    ip = "192.168.1.102"
    camera_url = get_camera_url(login=login, password=password, ip=ip)
else:
    camera_url = None

camera_processor = CameraProcessor(camera_url = camera_url)

# %%
image = camera_processor.live_feed()
# Out:
# Press 's' to save an image or 'q' to quit.
# Image saved to variable 'image'.
# Exiting.

# %%
image = camera_processor.capture_image()
camera_processor.show_image(image, fig_size=(8,8))

# %%
from libs.aruco import *
aruco_detector = ArucoDetector()
corrected_image = aruco_detector.correct_perspective(image, find_matrix = True)

# %%
camera_processor.show_image(image)
